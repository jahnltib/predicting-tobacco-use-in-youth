# %%
# Use this helper to generate a list of columnID's to remove from a dataframe. 
# If you need to change removed pairs, add the # REMOVE tag to any line in the annotate_this_map.py file.
# The script will extract the columnID's and write them to a new file called drop_list.py

def extract_removed_pairs(file_path, output_file_path):
    removed_pairs = set()
    
    with open(file_path, 'r') as file:
        for line_num, line in enumerate(file, 1):
            line = line.strip()
            print(f"Processing line {line_num}: {line}")
            
            if '# REMOVE' in line:
                # Split and clean key, then process it
                key_value_pair = line.split(':', 1)
                if len(key_value_pair) > 1:
                    key = key_value_pair[0].strip().replace('"', '')  # Remove any extra quotes
                    key = key.lower()  # Convert entire key to lowercase
                    if key.startswith("qn"):
                        key = "QN" + key[2:]  # Ensure only first two letters are uppercase
                    removed_pairs.add(key)
                    print(f"Added key: {key}")

    # Write the collected keys as a list of strings to the output file
    if removed_pairs:
        with open(output_file_path, 'w') as output_file:
            formatted_keys = ', '.join(f"'{key}'" for key in sorted(removed_pairs))
            output_file.write(f'dropped = [{formatted_keys}]')  # Output in list format

    print(f"Collected column IDs: {sorted(removed_pairs)}")
    print(f"Unique column IDs of questions tagged with # REMOVE have been exported to {output_file_path} as a list.")

# Usage
file_path = 'map_annotated.py'  # Replace with your actual file path
output_file_path = 'drop_list.py'  
extract_removed_pairs(file_path, output_file_path)
# Out:
# Processing line 1: questions = {
# Processing line 2: "Artificial_id": "Artificial Unique Identifier",
# Processing line 3: "LOCATION": "Where are you currently taking this survey?", # -> Categorical
# Processing line 4: "QN1": "How old are you?", # -> Categorical: 0-13, 14-18, 19+
# Processing line 5: "QN2": "What is your sex?", # -> Categorical
# Processing line 6: "QN3": "What grade are you in?", # -> Categorical: Middle School or High School
# Processing line 7: "QN4A": "Are you Hispanic, Latino, Latina, or of Spanish origin? (No, not of Hispanic, Latino, Latina, or Spanish origin)", # REMOVE: to avoid Dummy Variable Trap
# Added key: QN4a
# Processing line 8: "QN4B": "Are you Hispanic, Latino, Latina, or of Spanish origin? (Yes, Mexican, Mexican American, Chicano, or Chicana)",
# Processing line 9: "QN4C": "Are you Hispanic, Latino, Latina, or of Spanish origin? (Yes, Puerto Rican)",
# Processing line 10: "QN4D": "Are you Hispanic, Latino, Latina, or of Spanish origin? (Yes, Cuban)",
# Processing line 11: "QN4E": "Are you Hispanic, Latino, Latina, or of Spanish origin? (Yes, another Hispanic, Latino, Latina, or Spanish origin)",
# Processing line 12: "QN5A": "What race or races do you consider yourself to be? (American Indian or Alaska Native)",
# Processing line 13: "QN5B": "What race or races do you consider yourself to be? (Asian)",
# Processing line 14: "QN5C": "What race or races do you consider yourself to be? (Black or African American)",
# Processing line 15: "QN5D": "What race or races do you consider yourself to be? (Native Hawaiian or Other Pacific Islander)",
# Processing line 16: "QN5E": "What race or races do you consider yourself to be? (White)",
# Processing line 17: "QN6": "Have you ever used an e-cigarette, even once or twice?",
# Processing line 18: "QN7": "How old were you when you first used an e-cigarette, even once or twice?",
# Processing line 19: "QN8": "In total, on how many days have you used e-cigarettes in your entire life?",
# Processing line 20: "QN9": "During the past 30 days, on how many days did you use e-cigarettes?", # -> Categorical: 0, > 0 (treat them as e-cigarette users or non-users)
# Processing line 21: "QN10": "When was the last time you used an e-cigarette, even one or two times?", # REMOVE
# Added key: QN10
# Processing line 22: "QN11A": "Why did you first use an e-cigarette? (A friend used them)", # MERGE to NC1 : "Respondent used e-cigarettes due to exposure from friends, media, or family"
# Processing line 23: "QN11B": "Why did you first use an e-cigarette? (A family member used them)", # MERGE to NC1 : "Respondent used e-cigarettes due to exposure from friends, media, or family"
# Processing line 24: "QN11C": "Why did you first use an e-cigarette? (To try to quit using other tobacco products, such as cigarettes)", # REMOVE
# Added key: QN11c
# Processing line 25: "QN11D": "Why did you first use an e-cigarette? (They cost less than other tobacco products, such as cigarettes)", # REMOVE
# Added key: QN11d
# Processing line 26: "QN11E": "Why did you first use an e-cigarette? (They were easier to get than other tobacco products, such as cigarettes)",
# Processing line 27: "QN11F": "Why did you first use an e-cigarette? ( I’ve seen people on TV, online, or in movies use them)", # MERGE to NC1 : "Respondent used e-cigarettes due to exposure from friends, media, or family"
# Processing line 28: "QN11G": "Why did you first use an e-cigarette? (They are less harmful than other forms of tobacco, such as cigarettes)", # REMOVE
# Added key: QN11g
# Processing line 29: "QN11H": "Why did you first use an e-cigarette? (They were available in flavors, such as menthol, mint, candy, fruit, or chocolate)", # REMOVE
# Added key: QN11h
# Processing line 30: "QN11I": "Why did you first use an e-cigarette? (I could use them unnoticed at home or at school)", # REMOVE
# Added key: QN11i
# Processing line 31: "QN11J": "Why did you first use an e-cigarette? (I could use them to do tricks)", # REMOVE
# Added key: QN11j
# Processing line 32: "QN11K": "Why did you first use an e-cigarette? (I was curious about them)", # REMOVE
# Added key: QN11k
# Processing line 33: "QN11L": "Why did you first use an e-cigarette? (I was feeling anxious, stressed, or depressed)",
# Processing line 34: "QN11M": "Why did you first use an e-cigarette? (To get a high or buzz from nicotine)", # REMOVE
# Added key: QN11m
# Processing line 35: "QN11N": "Why did you first use an e-cigarette? (I used them for some other reason)", # REMOVE
# Added key: QN11n
# Processing line 36: "QN12A": "Why do you currently use e-cigarettes? (A friend uses them)", # MERGE to NC1 : "Respondent used e-cigarettes due to exposure from friends, media, or family"
# Processing line 37: "QN12B": "Why do you currently use e-cigarettes? (A family member uses them)", # MERGE to NC1 : "Respondent used e-cigarettes due to exposure from friends, media, or family"
# Processing line 38: "QN12C": "Why do you currently use e-cigarettes? (To try to quit using other tobacco products, such as cigarettes)", # REMOVE
# Added key: QN12c
# Processing line 39: "QN12D": "Why do you currently use e-cigarettes? (They cost less than other tobacco products, such as cigarettes)", # REMOVE
# Added key: QN12d
# Processing line 40: "QN12E": "Why do you currently use e-cigarettes? (They are easier to get than other tobacco products, such as cigarettes)",
# Processing line 41: "QN12F": "Why do you currently use e-cigarettes? ( I’ve seen people on TV, online, or in movies use them)", # MERGE to NC1 : "Respondent used e-cigarettes due to exposure from friends, media, or family"
# Processing line 42: "QN12G": "Why do you currently use e-cigarettes? (They are less harmful than other forms of tobacco, such as cigarettes)", # REMOVE
# Added key: QN12g
# Processing line 43: "QN12H": "Why do you currently use e-cigarettes? (They are available in flavors, such as menthol, mint, candy, fruit, or chocolate)",
# Processing line 44: "QN12I": "Why do you currently use e-cigarettes? (I can use them unnoticed at home or at school)", # REMOVE
# Added key: QN12i
# Processing line 45: "QN12J": "Why do you currently use e-cigarettes? (I can use them to do tricks)", # REMOVE
# Added key: QN12j
# Processing line 46: "QN12K": "Why do you currently use e-cigarettes? (I am curious about them)", # REMOVE
# Added key: QN12k
# Processing line 47: "QN12L": "Why do you currently use e-cigarettes? (Because I feel anxious, stressed, or depressed)", # MERGE to NC2: "Respondent has a bad mental state such as anxiety, stress, or depression"
# Processing line 48: "QN12M": "Why do you currently use e-cigarettes? (To get a high or buzz from nicotine)", # REMOVE
# Added key: QN12m
# Processing line 49: "QN12N": "Why do you currently use e-cigarettes? (I use them for some other reason)", # REMOVE
# Added key: QN12n
# Processing line 50: "QN13": "Which of the following best describes the type of e-cigarette you have used in the past 30 days?", # REMOVE
# Added key: QN13
# Processing line 51: "QN14A": "During the past 30 days, what e-cigarette brands did you use? (blu)", # REMOVE
# Added key: QN14a
# Processing line 52: "QN14B": "During the past 30 days, what e-cigarette brands did you use? (Breeze)", # REMOVE
# Added key: QN14b
# Processing line 53: "QN14C": "During the past 30 days, what e-cigarette brands did you use? (Elf Bar)", # REMOVE
# Added key: QN14c
# Processing line 54: "QN14D": "During the past 30 days, what e-cigarette brands did you use? (Esco Bars)", # REMOVE
# Added key: QN14d
# Processing line 55: "QN14E": "During the past 30 days, what e-cigarette brands did you use? (Fume)", # REMOVE
# Added key: QN14e
# Processing line 56: "QN14F": "During the past 30 days, what e-cigarette brands did you use? (JUUL)", # REMOVE
# Added key: QN14f
# Processing line 57: "QN14G": "During the past 30 days, what e-cigarette brands did you use? (HQD)", # REMOVE
# Added key: QN14g
# Processing line 58: "QN14H": "During the past 30 days, what e-cigarette brands did you use? (Kangvape (including Onee Stick))", # REMOVE
# Added key: QN14h
# Processing line 59: "QN14I": "During the past 30 days, what e-cigarette brands did you use? (Logic)", # REMOVE
# Added key: QN14i
# Processing line 60: "QN14K": "During the past 30 days, what e-cigarette brands did you use? (NJOY)", # REMOVE
# Added key: QN14k
# Processing line 61: "QN14L": "During the past 30 days, what e-cigarette brands did you use? (SMOK (including NOVO))", # REMOVE
# Added key: QN14l
# Processing line 62: "QN14M": "During the past 30 days, what e-cigarette brands did you use? (Suorin (including Air Bar))", # REMOVE
# Added key: QN14m
# Processing line 63: "QN14N": "During the past 30 days, what e-cigarette brands did you use? (Vuse)", # REMOVE
# Added key: QN14n
# Processing line 64: "QN14O": "During the past 30 days, what e-cigarette brands did you use? (Some other brand(s) not listed here)", # REMOVE
# Added key: QN14o
# Processing line 65: "QN14P": "During the past 30 days, what e-cigarette brands did you use? (Not sure / I don’t know the brand)", # REMOVE
# Added key: QN14p
# Processing line 66: "QN15": "During the past 30 days, what brand of e-cigarettes did you usually use?", # REMOVE
# Added key: QN15
# Processing line 67: "QN16": "Did any of the e-cigarettes that you used in the past 30 days contain nicotine?", # MERGE to NC3: "Respondent used e-cigarettes with nicotine or nicotine salts"
# Processing line 68: "QN17": "Did any of the e-cigarettes that you used in the past 30 days contain nicotine salts?", # MERGE to NC3: "Respondent used e-cigarettes with nicotine or nicotine salts"
# Processing line 69: "QN18A_A": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Tobacco-flavor)", # REMOVE
# Added key: QN18a_a
# Processing line 70: "QN18A_B": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18a_b
# Processing line 71: "QN18A_C": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Mint)", # REMOVE
# Added key: QN18a_c
# Processing line 72: "QN18A_D": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18a_d
# Processing line 73: "QN18A_E": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18a_e
# Processing line 74: "QN18A_F": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18a_f
# Processing line 75: "QN18A_G": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18a_g
# Processing line 76: "QN18A_H": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Non-alcoholic drink (such as coffee, soda, lemonade, or other beverage))", # REMOVE
# Added key: QN18a_h
# Processing line 77: "QN18A_I": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18a_i
# Processing line 78: "QN18A_J": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Unflavored)", # REMOVE
# Added key: QN18a_j
# Processing line 79: "QN18A_K": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Some other flavor not listed here)", # REMOVE
# Added key: QN18a_k
# Processing line 80: "QN18B_A": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Tobacco-flavor)", # REMOVE
# Added key: QN18b_a
# Processing line 81: "QN18B_B": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18b_b
# Processing line 82: "QN18B_C": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Mint)", # REMOVE
# Added key: QN18b_c
# Processing line 83: "QN18B_D": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18b_d
# Processing line 84: "QN18B_E": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18b_e
# Processing line 85: "QN18B_F": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18b_f
# Processing line 86: "QN18B_G": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18b_g
# Processing line 87: "QN18B_H": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Non-alcoholic drink (such as coffee, soda, lemonade, or other beverage))", # REMOVE
# Added key: QN18b_h
# Processing line 88: "QN18B_I": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18b_i
# Processing line 89: "QN18B_J": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Some other flavor not listed here)", # REMOVE
# Added key: QN18b_j
# Processing line 90: "QN18C_A": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Tobacco-flavor)", # REMOVE
# Added key: QN18c_a
# Processing line 91: "QN18C_B": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18c_b
# Processing line 92: "QN18C_C": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Mint)", # REMOVE
# Added key: QN18c_c
# Processing line 93: "QN18C_D": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18c_d
# Processing line 94: "QN18C_E": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18c_e
# Processing line 95: "QN18C_F": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18c_f
# Processing line 96: "QN18C_G": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18c_g
# Processing line 97: "QN18C_H": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Non-alcoholic drink (such as coffee, soda, lemonade, or other beverage))", # REMOVE
# Added key: QN18c_h
# Processing line 98: "QN18C_I": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18c_i
# Processing line 99: "QN18C_J": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Some other flavor not listed here", # REMOVE
# Added key: QN18c_j
# Processing line 100: "QN18D_A": "In the past 30 days when you used snus, what flavors did you use? (Tobacco- flavor)", # REMOVE
# Added key: QN18d_a
# Processing line 101: "QN18D_B": "In the past 30 days when you used snus, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18d_b
# Processing line 102: "QN18D_C": "In the past 30 days when you used snus, what flavors did you use? (Mint)", # REMOVE
# Added key: QN18d_c
# Processing line 103: "QN18D_D": "In the past 30 days when you used snus, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18d_d
# Processing line 104: "QN18D_E": "In the past 30 days when you used snus, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18d_e
# Processing line 105: "QN18D_F": "In the past 30 days when you used snus, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18d_f
# Processing line 106: "QN18D_G": "In the past 30 days when you used snus, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18d_g
# Processing line 107: "QN18D_H": "In the past 30 days when you used snus, what flavors did you use? (Non- alcoholic drinks (such as coffee, soda, lemonade, or other beverage))", # REMOVE
# Added key: QN18d_h
# Processing line 108: "QN18D_I": "In the past 30 days when you used snus, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18d_i
# Processing line 109: "QN18D_J": "In the past 30 days when you used snus, what flavors did you use? (Some other flavor not listed here)", # REMOVE
# Added key: QN18d_j
# Processing line 110: "QN18E_A": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Tobacco-flavor)", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 111: "QN18E_B": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Menthol)", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 112: "QN18E_C": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Mint)", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 113: "QN18E_D": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 114: "QN18E_E": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Fruit)", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 115: "QN18E_F": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Chocolate)", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 116: "QN18E_G": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 117: "QN18E_H": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Non-alcholohic drinks (such as coffee, soda, lemonade, or other beverage))", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 118: "QN18E_I": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Candy, desserts, or other sweets)", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 119: "QN18E_J": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Unflavored)", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 120: "QN18E_K": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Some other flavor not listed here)", # MERGE to NC4: "Respondent used nicotine pouches"
# Processing line 121: "QN18F_A": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Tobacco-flavor)", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 122: "QN18F_B": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Menthol)", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 123: "QN18F_C": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Mint)", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 124: "QN18F_D": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 125: "QN18F_E": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Fruit)", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 126: "QN18F_F": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Chocolate)", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 127: "QN18F_G": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 128: "QN18F_H": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Non-alcoholic drinks (such as coffee, soda, lemonade, or other beverage))", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 129: "QN18F_I": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Candy, desserts, or other sweets)", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 130: "QN18F_J": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Unflavored)", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 131: "QN18F_K": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Some other flavor not listed here", # MERGE to NC5: "Respondent used oral nicotine products"
# Processing line 132: "QN18G_A": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Tobacco-flavor)", # REMOVE
# Added key: QN18g_a
# Processing line 133: "QN18G_B": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18g_b
# Processing line 134: "QN18G_C": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Mint)", # REMOVE
# Added key: QN18g_c
# Processing line 135: "QN18G_D": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18g_d
# Processing line 136: "QN18G_E": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18g_e
# Processing line 137: "QN18G_F": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18g_f
# Processing line 138: "QN18G_G": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18g_g
# Processing line 139: "QN18G_H": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Non-alcoholic drinks (such as coffee, soda, lemonade, or other beverage))", # REMOVE
# Added key: QN18g_h
# Processing line 140: "QN18G_I": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18g_i
# Processing line 141: "QN18G_J": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Some other flavor not listed here", # REMOVE
# Added key: QN18g_j
# Processing line 142: "QN18H_A": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Tobacco-flavor)", # REMOVE
# Added key: QN18h_a
# Processing line 143: "QN18H_B": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18h_b
# Processing line 144: "QN18H_C": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Mint)", # REMOVE
# Added key: QN18h_c
# Processing line 145: "QN18H_D": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18h_d
# Processing line 146: "QN18H_E": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18h_e
# Processing line 147: "QN18H_F": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18h_f
# Processing line 148: "QN18H_G": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18h_g
# Processing line 149: "QN18H_H": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Non-alcoholic drinks (such as coffee, soda, lemonade, or other beverage))", # REMOVE
# Added key: QN18h_h
# Processing line 150: "QN18H_I": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18h_i
# Processing line 151: "QN18H_J": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Unflavored)", # REMOVE
# Added key: QN18h_j
# Processing line 152: "QN18H_K": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Some other flavor not listed here)", # REMOVE
# Added key: QN18h_k
# Processing line 153: "QN18I_A": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Tobacco-flavor)", # REMOVE
# Added key: QN18i_a
# Processing line 154: "QN18I_B": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18i_b
# Processing line 155: "QN18I_C": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Mint)", # REMOVE
# Added key: QN18i_c
# Processing line 156: "QN18I_D": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18i_d
# Processing line 157: "QN18I_E": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18i_e
# Processing line 158: "QN18I_F": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18i_f
# Processing line 159: "QN18I_G": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18i_g
# Processing line 160: "QN18I_H": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Non-alcoholic drinks (such as coffee, soda, lemonade, or other beverages))", # REMOVE
# Added key: QN18i_h
# Processing line 161: "QN18I_I": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18i_i
# Processing line 162: "QN18I_J": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Some other flavor not listed here)", # REMOVE
# Added key: QN18i_j
# Processing line 163: "QN18J_A": "In the past 30 days when you used bidis, what flavors did you use? (Tobacco- flavor)", # REMOVE
# Added key: QN18j_a
# Processing line 164: "QN18J_B": "In the past 30 days when you used bidis, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18j_b
# Processing line 165: "QN18J_C": "In the past 30 days when you used bidis, what flavors did you use? (Mint", # REMOVE
# Added key: QN18j_c
# Processing line 166: "QN18J_D": "In the past 30 days when you used bidis, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18j_d
# Processing line 167: "QN18J_E": "In the past 30 days when you used bidis, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18j_e
# Processing line 168: "QN18J_F": "In the past 30 days when you used bidis, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18j_f
# Processing line 169: "QN18J_G": "In the past 30 days when you used bidis, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18j_g
# Processing line 170: "QN18J_H": "In the past 30 days when you used bidis, what flavors did you use? (Non- alcoholic drinks (such as coffee, soda, lemonade, or other beverages))", # REMOVE
# Added key: QN18j_h
# Processing line 171: "QN18J_I": "In the past 30 days when you used bidis, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18j_i
# Processing line 172: "QN18J_J": "In the past 30 days when you used bidis, what flavors did you use? (Some other flavor not listed here)", # REMOVE
# Added key: QN18j_j
# Processing line 173: "QN18K_A": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Tobacco-flavor)", # REMOVE
# Added key: QN18k_a
# Processing line 174: "QN18K_B": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Menthol)", # REMOVE
# Added key: QN18k_b
# Processing line 175: "QN18K_C": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Mint)", # REMOVE
# Added key: QN18k_c
# Processing line 176: "QN18K_D": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Spice (such as cinnamon, vanilla, or clove))", # REMOVE
# Added key: QN18k_d
# Processing line 177: "QN18K_E": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Fruit)", # REMOVE
# Added key: QN18k_e
# Processing line 178: "QN18K_F": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Chocolate)", # REMOVE
# Added key: QN18k_f
# Processing line 179: "QN18K_G": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Alcoholic drinks (such as wine, margarita, or other cocktails))", # REMOVE
# Added key: QN18k_g
# Processing line 180: "QN18K_H": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Non-alcoholic drinks (such as coffee, soda, lemonade, or other beverages))", # REMOVE
# Added key: QN18k_h
# Processing line 181: "QN18K_I": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Candy, desserts, or other sweets)", # REMOVE
# Added key: QN18k_i
# Processing line 182: "QN18K_J": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Some other flavor not listed here)", # REMOVE
# Added key: QN18k_j
# Processing line 183: "QN19": "Did any of the flavors that you used in the past 30 days have names or descriptions that included the word “ice” or “iced” (for example, blueberry ice or strawberry ice)?", # REMOVE
# Added key: QN19
# Processing line 184: "QN20": "Did any of the flavors that you used in the past 30 days have a name that did not describe a specific flavor, such as “solar,” “purple,” “jazz,” “island bash,” “fusion” or some other word or phrase?", # REMOVE
# Added key: QN20
# Processing line 185: "QN21A_A": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (I bought them myself)", # MERGE to NC6: "Respondent has had access to e-cigarettes through self-purchase, a friend, or family member"
# Processing line 186: "QN21A_B": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (I had someone else buy them for me)", # MERGE to NC6: "Respondent has had access to e-cigarettes through self-purchase, a friend, or family member"
# Processing line 187: "QN21A_C": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (I asked someone to give me some)", # MERGE to NC6: "Respondent has had access to e-cigarettes through self-purchase, a friend, or family member"
# Processing line 188: "QN21A_D": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (Someone offered them to me)", # MERGE to NC6: "Respondent has had access to e-cigarettes through self-purchase, a friend, or family member"
# Processing line 189: "QN21A_E": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (I got them from a friend)", # MERGE to NC6: "Respondent has had access to e-cigarettes through self-purchase, a friend, or family member"
# Processing line 190: "QN21A_F": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (I got them from a family member)", # MERGE to NC6: "Respondent has had access to e-cigarettes through self-purchase, a friend, or family member"
# Processing line 191: "QN21A_G": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (I took them from a store or another person)", # MERGE to NC6: "Respondent has had access to e-cigarettes through self-purchase, a friend, or family member"
# Processing line 192: "QN21A_H": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (I got them in some other way)", # REMOVE
# Added key: QN21a_h
# Processing line 193: "QN21B_A": "During the past 30 days, how did you get your cigarettes? (I bought them myself)", # REMOVE
# Added key: QN21b_a
# Processing line 194: "QN21B_B": "During the past 30 days, how did you get your cigarettes? (I had someone else buy them for me)", # REMOVE
# Added key: QN21b_b
# Processing line 195: "QN21B_C": "During the past 30 days, how did you get your cigarettes? (I asked someone to give me some)", # REMOVE
# Added key: QN21b_c
# Processing line 196: "QN21B_D": "During the past 30 days, how did you get your cigarettes? (Someone offered them to me)", # REMOVE
# Added key: QN21b_d
# Processing line 197: "QN21B_E": "During the past 30 days, how did you get your cigarettes? (I got them from a friend)", # REMOVE
# Added key: QN21b_e
# Processing line 198: "QN21B_F": "During the past 30 days, how did you get your cigarettes? (I got them from a family member)", # REMOVE
# Added key: QN21b_f
# Processing line 199: "QN21B_G": "During the past 30 days, how did you get your cigarettes? (I took them from a store or another person)", # REMOVE
# Added key: QN21b_g
# Processing line 200: "QN21B_H": "During the past 30 days, how did you get your cigarettes? (I got them in some other way)", # REMOVE
# Added key: QN21b_h
# Processing line 201: "QN21C_A": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (I bought them myself)", # REMOVE
# Added key: QN21c_a
# Processing line 202: "QN21C_B": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (I had someone else buy them for me)", # REMOVE
# Added key: QN21c_b
# Processing line 203: "QN21C_C": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (I asked someone to give me some)", # REMOVE
# Added key: QN21c_c
# Processing line 204: "QN21C_D": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (Someone offered them to me)", # REMOVE
# Added key: QN21c_d
# Processing line 205: "QN21C_E": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (I got them from a friend)", # REMOVE
# Added key: QN21c_e
# Processing line 206: "QN21C_F": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (I got them from a family member)", # REMOVE
# Added key: QN21c_f
# Processing line 207: "QN21C_G": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (I took them from a store or another person)", # REMOVE
# Added key: QN21c_g
# Processing line 208: "QN21C_H": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (I got them in some other way)", # REMOVE
# Added key: QN21c_h
# Processing line 209: "QN21D_A": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (I bought it myself)", # REMOVE
# Added key: QN21d_a
# Processing line 210: "QN21D_B": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (I had someone else buy it for me)", # REMOVE
# Added key: QN21d_b
# Processing line 211: "QN21D_C": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (I asked someone to give me some)", # REMOVE
# Added key: QN21d_c
# Processing line 212: "QN21D_D": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (Someone offered it to me)", # REMOVE
# Added key: QN21d_d
# Processing line 213: "QN21D_E": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (I got it from a friend)", # REMOVE
# Added key: QN21d_e
# Processing line 214: "QN21D_F": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (I got it from a family member)", # REMOVE
# Added key: QN21d_f
# Processing line 215: "QN21D_G": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (I took it from a store or another person)", # REMOVE
# Added key: QN21d_g
# Processing line 216: "QN21D_H": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (I got it in some other way)", # REMOVE
# Added key: QN21d_h
# Processing line 217: "QN21E_A": "During the past 30 days, how did you get your snus? (I bought it myself)", # REMOVE
# Added key: QN21e_a
# Processing line 218: "QN21E_B": "During the past 30 days, how did you get your snus? (I had someone else buy it for me", # REMOVE
# Added key: QN21e_b
# Processing line 219: "QN21E_C": "During the past 30 days, how did you get your snus? (I asked someone to give me some)", # REMOVE
# Added key: QN21e_c
# Processing line 220: "QN21E_D": "During the past 30 days, how did you get your snus? (Someone offered it to me)", # REMOVE
# Added key: QN21e_d
# Processing line 221: "QN21E_E": "During the past 30 days, how did you get your snus? (I got it from a friend)", # REMOVE
# Added key: QN21e_e
# Processing line 222: "QN21E_F": "During the past 30 days, how did you get your snus? (I got it from a family member)", # REMOVE
# Added key: QN21e_f
# Processing line 223: "QN21E_G": "During the past 30 days, how did you get your snus? (I took it from a store or another person)", # REMOVE
# Added key: QN21e_g
# Processing line 224: "QN21E_H": "During the past 30 days, how did you get your snus? (I got it in some other way)", # REMOVE
# Added key: QN21e_h
# Processing line 225: "QN21F_A": "During the past 30 days, how did you get your nicotine pouches? (I bought them myself)", # REMOVE
# Added key: QN21f_a
# Processing line 226: "QN21F_B": "During the past 30 days, how did you get your nicotine pouches? (I had someone else buy them for me)", # REMOVE
# Added key: QN21f_b
# Processing line 227: "QN21F_C": "During the past 30 days, how did you get your nicotine pouches? (I asked someone to give me some)", # REMOVE
# Added key: QN21f_c
# Processing line 228: "QN21F_D": "During the past 30 days, how did you get your nicotine pouches? (Someone offered them to me)", # REMOVE
# Added key: QN21f_d
# Processing line 229: "QN21F_E": "During the past 30 days, how did you get your nicotine pouches? (I got them from a friend)", # REMOVE
# Added key: QN21f_e
# Processing line 230: "QN21F_F": "During the past 30 days, how did you get your nicotine pouches? (I got them from a family member)", # REMOVE
# Added key: QN21f_f
# Processing line 231: "QN21F_G": "During the past 30 days, how did you get your nicotine pouches? (I took them from a store or another person)", # REMOVE
# Added key: QN21f_g
# Processing line 232: "QN21F_H": "During the past 30 days, how did you get your nicotine pouches? (I got them in some other way)", # REMOVE
# Added key: QN21f_h
# Processing line 233: "QN21G_A": "During the past 30 days, how did you get your oral nicotine products? (I bought them myself)", # REMOVE
# Added key: QN21g_a
# Processing line 234: "QN21G_B": "During the past 30 days, how did you get your oral nicotine products? (I had someone else buy them for me)", # REMOVE
# Added key: QN21g_b
# Processing line 235: "QN21G_C": "During the past 30 days, how did you get your oral nicotine products? (I asked someone to give me some)", # REMOVE
# Added key: QN21g_c
# Processing line 236: "QN21G_D": "During the past 30 days, how did you get your oral nicotine products? (Someone offered them to me)", # REMOVE
# Added key: QN21g_d
# Processing line 237: "QN21G_E": "During the past 30 days, how did you get your oral nicotine products? (I got them from a friend)", # REMOVE
# Added key: QN21g_e
# Processing line 238: "QN21G_F": "During the past 30 days, how did you get your oral nicotine products? (I got them from a family member)", # REMOVE
# Added key: QN21g_f
# Processing line 239: "QN21G_G": "During the past 30 days, how did you get your oral nicotine products? (I took them from a store or another person)", # REMOVE
# Added key: QN21g_g
# Processing line 240: "QN21G_H": "During the past 30 days, how did you get your oral nicotine products? (I got them in some other way)", # REMOVE
# Added key: QN21g_h
# Processing line 241: "QN21H_A": "During the past 30 days, how did you get your hookah tobacco? (I bought it myself)", # REMOVE
# Added key: QN21h_a
# Processing line 242: "QN21H_B": "During the past 30 days, how did you get your hookah tobacco? (I had someone else buy it for me)", # REMOVE
# Added key: QN21h_b
# Processing line 243: "QN21H_C": "During the past 30 days, how did you get your hookah tobacco? (I asked someone to give me some)", # REMOVE
# Added key: QN21h_c
# Processing line 244: "QN21H_D": "During the past 30 days, how did you get your hookah tobacco? (Someone offered it to me)", # REMOVE
# Added key: QN21h_d
# Processing line 245: "QN21H_E": "During the past 30 days, how did you get your hookah tobacco? (I got it from a friend)", # REMOVE
# Added key: QN21h_e
# Processing line 246: "QN21H_F": "During the past 30 days, how did you get your hookah tobacco? (I got it from a family member)", # REMOVE
# Added key: QN21h_f
# Processing line 247: "QN21H_G": "During the past 30 days, how did you get your hookah tobacco? (I took it from a store or another person)", # REMOVE
# Added key: QN21h_g
# Processing line 248: "QN21H_H": "During the past 30 days, how did you get your hookah tobacco? (I got it in some other way)", # REMOVE
# Added key: QN21h_h
# Processing line 249: "QN21I_A": "During the past 30 days, how did you get your heated tobacco products? (I bought them myself)", # REMOVE
# Added key: QN21i_a
# Processing line 250: "QN21I_B": "During the past 30 days, how did you get your heated tobacco products? (I had someone else buy them for me)", # REMOVE
# Added key: QN21i_b
# Processing line 251: "QN21I_C": "During the past 30 days, how did you get your heated tobacco products? (I asked someone to give me some", # REMOVE
# Added key: QN21i_c
# Processing line 252: "QN21I_D": "During the past 30 days, how did you get your heated tobacco products? (Someone offered them to me)", # REMOVE
# Added key: QN21i_d
# Processing line 253: "QN21I_E": "During the past 30 days, how did you get your heated tobacco products? (I got them from a friend)", # REMOVE
# Added key: QN21i_e
# Processing line 254: "QN21I_F": "During the past 30 days, how did you get your heated tobacco products? (I got them from a family member)", # REMOVE
# Added key: QN21i_f
# Processing line 255: "QN21I_G": "During the past 30 days, how did you get your heated tobacco products? (I took them from a store or another person)", # REMOVE
# Added key: QN21i_g
# Processing line 256: "QN21I_H": "During the past 30 days, how did you get your heated tobacco products? (I got them in some other way)", # REMOVE
# Added key: QN21i_h
# Processing line 257: "QN21J_A": "During the past 30 days, how did you get your pipe tobacco? (I bought it myself)", # REMOVE
# Added key: QN21j_a
# Processing line 258: "QN21J_B": "During the past 30 days, how did you get your pipe tobacco? (I had someone else buy it for me)", # REMOVE
# Added key: QN21j_b
# Processing line 259: "QN21J_C": "During the past 30 days, how did you get your pipe tobacco? (I asked someone to give me some)", # REMOVE
# Added key: QN21j_c
# Processing line 260: "QN21J_D": "During the past 30 days, how did you get your pipe tobacco? (Someone offered it to me)", # REMOVE
# Added key: QN21j_d
# Processing line 261: "QN21J_E": "During the past 30 days, how did you get your pipe tobacco? (I got it from a friend)", # REMOVE
# Added key: QN21j_e
# Processing line 262: "QN21J_F": "During the past 30 days, how did you get your pipe tobacco? (I got it from a family member)", # REMOVE
# Added key: QN21j_f
# Processing line 263: "QN21J_G": "During the past 30 days, how did you get your pipe tobacco? (I took it from a store or another person)", # REMOVE
# Added key: QN21j_g
# Processing line 264: "QN21J_H": "During the past 30 days, how did you get your pipe tobacco? (I got it in some other way)", # REMOVE
# Added key: QN21j_h
# Processing line 265: "QN21K_A": "During the past 30 days, how did you get your bidis? (I bought them myself)", # REMOVE
# Added key: QN21k_a
# Processing line 266: "QN21K_B": "During the past 30 days, how did you get your bidis? (I had someone else buy them for me)", # REMOVE
# Added key: QN21k_b
# Processing line 267: "QN21K_C": "During the past 30 days, how did you get your bidis? (I asked someone to give me some)", # REMOVE
# Added key: QN21k_c
# Processing line 268: "QN21K_D": "During the past 30 days, how did you get your bidis? (Someone offered them to me)", # REMOVE
# Added key: QN21k_d
# Processing line 269: "QN21K_E": "During the past 30 days, how did you get your bidis? (I got them from a friend)", # REMOVE
# Added key: QN21k_e
# Processing line 270: "QN21K_F": "During the past 30 days, how did you get your bidis? (I got them from a family member)", # REMOVE
# Added key: QN21k_f
# Processing line 271: "QN21K_G": "During the past 30 days, how did you get your bidis? (I took them from a store or another person)", # REMOVE
# Added key: QN21k_g
# Processing line 272: "QN21K_H": "During the past 30 days, how did you get your bidis? (I got them in some other way)", # REMOVE
# Added key: QN21k_h
# Processing line 273: "QN21L_A": "During the past 30 days, how did you get your roll-your-own cigarettes? (I bought them myself)", # REMOVE
# Added key: QN21l_a
# Processing line 274: "QN21L_B": "During the past 30 days, how did you get your roll-your-own cigarettes? (I had someone else buy them for me)", # REMOVE
# Added key: QN21l_b
# Processing line 275: "QN21L_C": "During the past 30 days, how did you get your roll-your-own cigarettes? (I asked someone to give me some", # REMOVE
# Added key: QN21l_c
# Processing line 276: "QN21L_D": "During the past 30 days, how did you get your roll-your-own cigarettes? (Someone offered them to me)", # REMOVE
# Added key: QN21l_d
# Processing line 277: "QN21L_E": "During the past 30 days, how did you get your roll-your-own cigarettes? (I got them from a friend)", # REMOVE
# Added key: QN21l_e
# Processing line 278: "QN21L_F": "During the past 30 days, how did you get your roll-your-own cigarettes? (I got them from a family member)", # REMOVE
# Added key: QN21l_f
# Processing line 279: "QN21L_G": "During the past 30 days, how did you get your roll-your-own cigarettes? (I took them from a store or another person)", # REMOVE
# Added key: QN21l_g
# Processing line 280: "QN21L_H": "During the past 30 days, how did you get your roll-your-own cigarettes? (I got them in some other way)", # REMOVE
# Added key: QN21l_h
# Processing line 281: "QN22A_A": "During the past 30 days, where did you buy your e-cigarette devices, pods, cartridges, or e-liquid refills? (I did not buy e-cigarettes during the past 30 days)", # REMOVE
# Added key: QN22a_a
# Processing line 282: "QN22A_B": "During the past 30 days, where did you buy your e-cigarette devices, pods, cartridges, or e-liquid refills? (I bought them from another person (a friend, family member, or someone else))",  # REMOVE
# Added key: QN22a_b
# Processing line 283: "QN22A_C": "During the past 30 days, where did you buy your e-cigarette devices, pods, cartridges, or e-liquid refills? (A gas station or convenience store)", # REMOVE
# Added key: QN22a_c
# Processing line 284: "QN22A_D": "During the past 30 days, where did you buy your e-cigarette devices, pods, cartridges, or e-liquid refills? (A grocery store)", # REMOVE
# Added key: QN22a_d
# Processing line 285: "QN22A_E": "During the past 30 days, where did you buy your e-cigarette devices, pods, cartridges, or e-liquid refills? (A drugstore)", # REMOVE
# Added key: QN22a_e
# Processing line 286: "QN22A_F": "During the past 30 days, where did you buy your e-cigarette devices, pods, cartridges, or e-liquid refills? (A mall or shopping center kiosk/stand)", # REMOVE
# Added key: QN22a_f
# ...
# Processing line 669: "QN139D": "How true are the following statements about your neighborhood? (I have seen people using or selling drugs in my neighborhood)", # CATEGORICAL: 1-2 (Unsafe Neighborhood) or 3-4 (Safe Neighborhood)
# Processing line 670: "QN139E": "How true are the following statements about your neighborhood? (In the morning or later in the day, I often see drunk people on the street in my neighborhood)", # REMOVE
# Added key: QN139e
# Processing line 671: "QN139F": "How true are the following statements about your neighborhood? (Most adults in my neighborhood respect the law)", # REMOVE
# Added key: QN139f
# Processing line 672: "QN139G": "How true are the following statements about your neighborhood? (I feel safe when I walk around my neighborhood by myself during the day)", # CATEGORICAL: 1-2 (Unsafe Neighborhood) or 3-4 (Safe Neighborhood)
# Processing line 673: "QN139H": "How true are the following statements about your neighborhood? (People who live in my neighborhood often damage or steal each other’s property)", # CATEGORICAL: 3-4 (Unsafe Neighborhood) or 1-2 (Safe Neighborhood)
# Processing line 674: "QN139I": "How true are the following statements about your neighborhood? (I feel safe when I walk around my neighborhood by myself at night)", # CATEGORICAL: 1-2 (Unsafe Neighborhood) or 3-4 (Safe Neighborhood)
# Processing line 675: "QN139J": "How true are the following statements about your neighborhood? (In my neighborhood, the people with the most money are the drug dealers)", # CATEGORICAL: 3-4 (Unsafe Neighborhood) or 1-2 (Safe Neighborhood)
# Processing line 676: "QN140": "Do you speak a language other than English at home?",
# Processing line 677: "QN141": "Which of these options best describes your sexual orientation", # REMOVE
# Added key: QN141
# Processing line 678: "QN142": "Which of the following best describes your gender?", # REMOVE
# Added key: QN142
# Processing line 679: "QN143": "Are you transgender?",
# Processing line 680: "QN144": "During the past two weeks, how often have you been bothered by any of the following problems? (Little interest or pleasure in doing things)", # CATEGORICAL: 1 (Good mental state) or >1 Moderate to severe mental distress"
# Processing line 681: "QN145": "During the past two weeks, how often have you been bothered by any of the following problems? (Feeling down, depressed, or hopeless)", # CATEGORICAL: 1 (Good mental state) or >1 Moderate to severe mental distress"
# Processing line 682: "QN146": "During the past two weeks, how often have you been bothered by any of the following problems? (Feeling nervous, anxious, or on edge)", # CATEGORICAL: 1 (Good mental state) or >1 Moderate to severe mental distress"
# Processing line 683: "QN147": "During the past two weeks, how often have you been bothered by any of the following problems? (Not being able to stop or control worrying)", # CATEGORICAL: 1 (Good mental state) or >1 Moderate to severe mental distress"
# Processing line 684: "QN148": "During the past 12 months, how would you describe your grades in school?", # Tricky one
# Processing line 685: "QN149": "Because of a physical, mental, or emotional condition, do you have serious difficulty concentrating, remembering, or making decisions?", # CATEGORICAL: 0 (Good mental state) or 1 Moderate to severe mental distress"
# Processing line 686: "Q11n_TEXT": "Why did you first use an e-cigarette? (Specify)", # From this point on, all TEXT columns will be DROPPED manually
# Processing line 687: "Q12n_TEXT": "Why do you currently use e-cigarettes? (Specify)", #
# Processing line 688: "Q14o_TEXT": "During the past 30 days, what e-cigarette brands did you use? (Specify)", #
# Processing line 689: "Q18a_k_TEXT": "In the past 30 days when you used e-cigarettes, what flavors did you use? (Specify)", #
# Processing line 690: "Q18b_j_TEXT": "In the past 30 days when you used cigars, cigarillos, or little cigars, what flavors did you use? (Specify)", #
# Processing line 691: "Q18c_j_TEXT": "In the past 30 days when you used smokeless tobacco, what flavors did you use? (Specify)", #
# Processing line 692: "Q18d_j_TEXT": "In the past 30 days when you used snus, what flavors did you use? (Specify", #
# Processing line 693: "Q18e_k_TEXT": "In the past 30 days that you used nicotine pouches, what flavors did you use? (Specify)", #
# Processing line 694: "Q18f_k_TEXT": "In the past 30 days when you used oral nicotine products, what flavors did you use? (Specify)", #
# Processing line 695: "Q18g_j_TEXT": "In the past 30 days when you used hookah or waterpipe, what flavors did you use? (Specify)", #
# Processing line 696: "Q18h_k_TEXT": "In the past 30 days when you used heated tobacco products, what flavors did you use? (Specify)", #
# Processing line 697: "Q18i_j_TEXT": "In the past 30 days when you smoked pipes filled with tobacco, what flavors did you use? (Specify)", #
# Processing line 698: "Q18j_j_TEXT": "In the past 30 days when you used bidis, what flavors did you use? (Specify", #
# Processing line 699: "Q18k_j_TEXT": "In the past 30 days when you used roll-your-own cigarettes, what flavors did you use? (Specify)", #
# Processing line 700: "Q20_TEXT": "Did any of the flavors that you used in the past 30 days have a name that did not describe a specific flavor, such as “solar,” “purple,” “jazz,” “island bash,” “fusion” or some other word or phrase? (Specify)", #
# Processing line 701: "Q21a_h_TEXT": "During the past 30 days, how did you get your e-cigarette devices, pods, cartridges, or e-liquid refills? (Specify)", #
# Processing line 702: "Q21b_h_TEXT": "During the past 30 days, how did you get your cigarettes? (Specify)", #
# Processing line 703: "Q21c_h_TEXT": "During the past 30 days, how did you get your cigars, cigarillos, or little cigars? (Specify)", #
# Processing line 704: "Q21d_h_TEXT": "During the past 30 days, how did you get your chewing tobacco, snuff, or dip? (Specify)", #
# Processing line 705: "Q21e_h_TEXT": "During the past 30 days, how did you get your snus? (Specify)", #
# Processing line 706: "Q21f_h_TEXT": "During the past 30 days, how did you get your nicotine pouches? (Specify)", #
# Processing line 707: "Q21g_h_TEXT": "During the past 30 days, how did you get your oral nicotine products? (Specify", #
# Processing line 708: "Q21h_h_TEXT": "During the past 30 days, how did you get your hookah tobacco? (Specify", #
# Processing line 709: "Q21i_h_TEXT": "During the past 30 days, how did you get your heated tobacco products? (Specify", #
# Processing line 710: "Q21j_h_TEXT": "During the past 30 days, how did you get your pipe tobacco? (Specify)", #
# Processing line 711: "Q21k_h_TEXT": "During the past 30 days, how did you get your bidis? (Specify)", #
# Processing line 712: "Q21l_h_TEXT": "During the past 30 days, how did you get your roll-your-own cigarettes? (Specify", #
# Processing line 713: "Q22a_l_TEXT": "During the past 30 days, where did you buy your e-cigarette devices, pods, cartridges, or e-liquid refills? (Specify)", #
# Processing line 714: "Q22b_l_TEXT": "During the past 30 days, where did you buy your cigarettes? (Specify)", #
# Processing line 715: "Q22c_l_TEXT": "During the past 30 days, where did you buy your cigars, cigarillos, or little cigars? (Specify)", #
# Processing line 716: "Q22d_l_TEXT": "During the past 30 days, where did you buy your chewing tobacco, snuff, or dip? (Specify)", #
# Processing line 717: "Q22e_l_TEXT": "During the past 30 days, where did you buy your snus? (Specify)", #
# Processing line 718: "Q22f_l_TEXT": "During the past 30 days, where did you buy your nicotine pouches? (Specify", #
# Processing line 719: "Q22g_l_TEXT": "During the past 30 days, where did you buy your oral nicotine products? (Specify", #
# Processing line 720: "Q22h_l_TEXT": "During the past 30 days, where did you buy your hookah tobacco? (Specify", #
# Processing line 721: "Q22i_l_TEXT": "During the past 30 days, where did you buy your heated tobacco products? (Specify", #
# Processing line 722: "Q22j_l_TEXT": "During the past 30 days, where did you buy your pipe tobacco? (Specify)", #
# Processing line 723: "Q22k_l_TEXT": "During the past 30 days, where did you buy your bidis? (Specify)", #
# Processing line 724: "Q22l_l_TEXT": "During the past 30 days, where did you buy your roll-your-own cigarettes? (Specify", #
# Processing line 725: "Q24d_TEXT": "During the past 30 days, which of the following e-cigarette product(s) did you get or buy from another person? (Specify", #
# Processing line 726: "Q29j_TEXT": "When you tried to quit using e-cigarettes, did you use any of the following? (Specify", #
# Processing line 727: "Q34d_TEXT": "Have you ever vaped any of the following substances (even once)? (Specify", #
# Processing line 728: "Q42l_TEXT": "During the past 30 days, what brands of cigarettes did you smoke? (Specify)", #
# Processing line 729: "Q57m_TEXT": "During the past 30 days, what brands of cigars, cigarillos, or little cigars did you smoke? (Specify)", #
# Processing line 730: "Q60_TEXT": "Did any of the flavors that you used in the past 30 days have a name that did not describe a specific flavor, such as “solar,” “purple,” “jazz,” “island bash,” “fusion” or some other word or phrase?", #
# Processing line 731: "Q70k_TEXT": "During the past 30 days, what brands of chewing tobacco, snuff, or dip did you use? (Specify)", #
# Processing line 732: "Q79h_TEXT": "During the past 30 days, what nicotine pouch brands did you use? (Specify)", #
# Processing line 733: "Q82_TEXT": "Did any of the flavors that you used in the past 30 days have a name that did not describe a specific flavor, such as “solar,” “purple,” “jazz,” “island bash,” “fusion” or some other word or phrase? (Specify)", #
# Processing line 734: "Q123i_TEXT": "On which social media sites have you seen posts or content related to e- cigarettes? (Specify)", #
# Processing line 735: "Q126g_TEXT": "Who usually posted the content related to e-cigarettes on your social media? (Specify)", #
# Processing line 736: "Q135e_TEXT": "While at school or on school property, have you ever seen anyone using an e-cigarette, such as JUUL, Vuse, NJOY, Elf Bar, or blu in any of the following locations? (Specify)", #
# Processing line 737: "Q141_TEXT": "Which of these options best describes your sexual orientation? (Specify)", #
# Processing line 738: "Q142_TEXT": "Which of the following best describes your gender? (Specify)", #
# Processing line 739: "AGEGRP": "The percentage of all students who reported their age to be < 18 years of age",
# Processing line 740: "SEX": "The percentage of all students who reported being either female or male",
# Processing line 741: "SCHOOLTYPE": "The percentage of all students who reported being in 6th, 7th, or 8th grade (middle school), or in 9th, 10th, 11th, or 12th grade (high school)",
# Processing line 742: "MRACE": "Number of races chosen from Q5",
# Processing line 743: "RACE_M": "Race/Eth - mult grp",
# Processing line 744: "RACE_S": "Race/Eth - no mult grp",
# Processing line 745: "SEXID": "The percentage of all students who reported being best described as straight/heterosexual, or gay/lesbian, or bisexual/pansexual/queer/asexual, or I not sure/questioning, or I do not know what this question means",
# Processing line 746: "SEXID2": "The percentage of all students who reported being best described as straight/heterosexual, or gay/lesbian/bisexual/pansexual/queer/asexual, or I am not sure/questioning, or I do not know what this question means",
# Processing line 747: "EBIDIS": "The percentage of all students who reported they have ever tried bidis (small brown cigarettes wrapped in a leaf)",
# Processing line 748: "PSU": "Primary Sampling Unit",
# Processing line 749: "PSU_NUM": "Primary Sampling Unit (Numeric)",
# Processing line 750: "Stratum": "Stratum for Variance",
# Processing line 751: "Stratum_num": "Stratum for Variance",
# Processing line 752: "WT_Analysis": "Final Weight",
# Processing line 753: }
# Collected column IDs: ['QN10', 'QN102', 'QN103', 'QN104', 'QN105', 'QN106', 'QN107', 'QN108', 'QN109', 'QN110', 'QN111', 'QN112', 'QN113', 'QN114', 'QN115', 'QN116', 'QN118', 'QN11c', 'QN11d', 'QN11g', 'QN11h', 'QN11i', 'QN11j', 'QN11k', 'QN11m', 'QN11n', 'QN123a', 'QN123b', 'QN123c', 'QN123d', 'QN123e', 'QN123f', 'QN123g', 'QN123h', 'QN123i', 'QN124', 'QN125', 'QN126a', 'QN126b', 'QN126c', 'QN126d', 'QN126e', 'QN126g', 'QN129', 'QN12c', 'QN12d', 'QN12g', 'QN12i', 'QN12j', 'QN12k', 'QN12m', 'QN12n', 'QN13', 'QN130', 'QN133', 'QN134', 'QN135f', 'QN136m', 'QN137f', 'QN137g', 'QN137o', 'QN138a', 'QN138b', 'QN138c', 'QN138d', 'QN138e', 'QN138f', 'QN138g', 'QN138h', 'QN138i', 'QN138j', 'QN138k', 'QN138l', 'QN138m', 'QN138n', 'QN138o', 'QN139e', 'QN139f', 'QN141', 'QN142', 'QN14a', 'QN14b', 'QN14c', 'QN14d', 'QN14e', 'QN14f', 'QN14g', 'QN14h', 'QN14i', 'QN14k', 'QN14l', 'QN14m', 'QN14n', 'QN14o', 'QN14p', 'QN15', 'QN18a_a', 'QN18a_b', 'QN18a_c', 'QN18a_d', 'QN18a_e', 'QN18a_f', 'QN18a_g', 'QN18a_h', 'QN18a_i', 'QN18a_j', 'QN18a_k', 'QN18b_a', 'QN18b_b', 'QN18b_c', 'QN18b_d', 'QN18b_e', 'QN18b_f', 'QN18b_g', 'QN18b_h', 'QN18b_i', 'QN18b_j', 'QN18c_a', 'QN18c_b', 'QN18c_c', 'QN18c_d', 'QN18c_e', 'QN18c_f', 'QN18c_g', 'QN18c_h', 'QN18c_i', 'QN18c_j', 'QN18d_a', 'QN18d_b', 'QN18d_c', 'QN18d_d', 'QN18d_e', 'QN18d_f', 'QN18d_g', 'QN18d_h', 'QN18d_i', 'QN18d_j', 'QN18g_a', 'QN18g_b', 'QN18g_c', 'QN18g_d', 'QN18g_e', 'QN18g_f', 'QN18g_g', 'QN18g_h', 'QN18g_i', 'QN18g_j', 'QN18h_a', 'QN18h_b', 'QN18h_c', 'QN18h_d', 'QN18h_e', 'QN18h_f', 'QN18h_g', 'QN18h_h', 'QN18h_i', 'QN18h_j', 'QN18h_k', 'QN18i_a', 'QN18i_b', 'QN18i_c', 'QN18i_d', 'QN18i_e', 'QN18i_f', 'QN18i_g', 'QN18i_h', 'QN18i_i', 'QN18i_j', 'QN18j_a', 'QN18j_b', 'QN18j_c', 'QN18j_d', 'QN18j_e', 'QN18j_f', 'QN18j_g', 'QN18j_h', 'QN18j_i', 'QN18j_j', 'QN18k_a', 'QN18k_b', 'QN18k_c', 'QN18k_d', 'QN18k_e', 'QN18k_f', 'QN18k_g', 'QN18k_h', 'QN18k_i', 'QN18k_j', 'QN19', 'QN20', 'QN21a_h', 'QN21b_a', 'QN21b_b', 'QN21b_c', 'QN21b_d', 'QN21b_e', 'QN21b_f', 'QN21b_g', 'QN21b_h', 'QN21c_a', 'QN21c_b', 'QN21c_c', 'QN21c_d', 'QN21c_e', 'QN21c_f', 'QN21c_g', 'QN21c_h', 'QN21d_a', 'QN21d_b', 'QN21d_c', 'QN21d_d', 'QN21d_e', 'QN21d_f', 'QN21d_g', 'QN21d_h', 'QN21e_a', 'QN21e_b', 'QN21e_c', 'QN21e_d', 'QN21e_e', 'QN21e_f', 'QN21e_g', 'QN21e_h', 'QN21f_a', 'QN21f_b', 'QN21f_c', 'QN21f_d', 'QN21f_e', 'QN21f_f', 'QN21f_g', 'QN21f_h', 'QN21g_a', 'QN21g_b', 'QN21g_c', 'QN21g_d', 'QN21g_e', 'QN21g_f', 'QN21g_g', 'QN21g_h', 'QN21h_a', 'QN21h_b', 'QN21h_c', 'QN21h_d', 'QN21h_e', 'QN21h_f', 'QN21h_g', 'QN21h_h', 'QN21i_a', 'QN21i_b', 'QN21i_c', 'QN21i_d', 'QN21i_e', 'QN21i_f', 'QN21i_g', 'QN21i_h', 'QN21j_a', 'QN21j_b', 'QN21j_c', 'QN21j_d', 'QN21j_e', 'QN21j_f', 'QN21j_g', 'QN21j_h', 'QN21k_a', 'QN21k_b', 'QN21k_c', 'QN21k_d', 'QN21k_e', 'QN21k_f', 'QN21k_g', 'QN21k_h', 'QN21l_a', 'QN21l_b', 'QN21l_c', 'QN21l_d', 'QN21l_e', 'QN21l_f', 'QN21l_g', 'QN21l_h', 'QN22a_a', 'QN22a_b', 'QN22a_c', 'QN22a_d', 'QN22a_e', 'QN22a_f', 'QN22a_g', 'QN22a_h', 'QN22a_i', 'QN22a_j', 'QN22a_k', 'QN22a_l', 'QN22b_a', 'QN22b_b', 'QN22b_c', 'QN22b_d', 'QN22b_e', 'QN22b_f', 'QN22b_g', 'QN22b_h', 'QN22b_i', 'QN22b_j', 'QN22b_k', 'QN22b_l', 'QN22c_a', 'QN22c_b', 'QN22c_c', 'QN22c_d', 'QN22c_e', 'QN22c_f', 'QN22c_g', 'QN22c_h', 'QN22c_i', 'QN22c_j', 'QN22c_k', 'QN22c_l', 'QN22d_a', 'QN22d_b', 'QN22d_c', 'QN22d_d', 'QN22d_e', 'QN22d_f', 'QN22d_g', 'QN22d_h', 'QN22d_i', 'QN22d_j', 'QN22d_k', 'QN22d_l', 'QN22e_a', 'QN22e_b', 'QN22e_c', 'QN22e_d', 'QN22e_e', 'QN22e_f', 'QN22e_g', 'QN22e_h', 'QN22e_i', 'QN22e_j', 'QN22e_k', 'QN22e_l', 'QN22f_a', 'QN22f_b', 'QN22f_c', 'QN22f_d', 'QN22f_e', 'QN22f_f', 'QN22f_g', 'QN22f_h', 'QN22f_i', 'QN22f_j', 'QN22f_k', 'QN22f_l', 'QN22g_a', 'QN22g_b', 'QN22g_c', 'QN22g_d', 'QN22g_e', 'QN22g_f', 'QN22g_g', 'QN22g_h', 'QN22g_i', 'QN22g_j', 'QN22g_k', 'QN22g_l', 'QN22h_a', 'QN22h_b', 'QN22h_c', 'QN22h_d', 'QN22h_e', 'QN22h_f', 'QN22h_g', 'QN22h_h', 'QN22h_i', 'QN22h_j', 'QN22h_k', 'QN22h_l', 'QN22i_a', 'QN22 ...
# Unique column IDs of questions tagged with # REMOVE have been exported to drop_list.py as a list.
